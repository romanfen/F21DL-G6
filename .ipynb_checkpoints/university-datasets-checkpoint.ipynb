# %% [markdown]
# # Setup

# %% [markdown]
# ### Importing all the dependencies for working with the dataset.

# %%
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/Ya2001/F21DL-G6/master/universities.csv"
UNI_PATH = os.path.join("datasets", "university")
UNI_URL = DOWNLOAD_ROOT + "datasets/university/universities.csv"

#ran into issues using this to download data locally

# %%
# def load_uni_data(uni_path=UNI_PATH):
#     csv_path = os.path.join(uni_path, "universities.csv")
#     return pd.read_csv(csv_path)

# Also could not use this method 
url = "https://raw.githubusercontent.com/Ya2001/F21DL-G6/master/universities.csv"
uni = pd.read_csv(url)

# %%
uni.info()

# Note that the info function is reporting that there are no missing data values, this is untrue.
# The data that is missing was marked with the character "-"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   World Rank                 2000 non-null   int64
#  1   Institution                2000 non-null   object
#  2   Country                    2000 non-null   object
#  3   National Rank              2000 non-null   int64
#  4   Quality of Education Rank  2000 non-null   object
#  5   Alumni Employment Rank     2000 non-null   object
#  6   Quality of Faculty Rank    2000 non-null   object
#  7   Research Performance Rank  2000 non-null   object
#  8   Score                      2000 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 140.8+ KB

# %% [markdown]
# ~~Using this info table we can see that out of the 2000 records, we have 2000 non-null entries. This means we do not have any missing values that we need to deal with during pre-processing of our data.~~
# Consider replacing above text with the comments in line [6]

# %%
#Viewing the dataset in a dataframe can showcase the records with missing data
uni.head(2000)
# Out:
#       World Rank                                 Institution         Country  \
# 0              1                          Harvard University             USA
# 1              2       Massachusetts Institute of Technology             USA
# 2              3                         Stanford University             USA
# 3              4                     University of Cambridge  United Kingdom
# 4              5                        University of Oxford  United Kingdom
# ...          ...                                         ...             ...
# 1995        1996             Santa Catarina State University          Brazil
# 1996        1997            Yancheng Institute of Technology           China
# 1997        1998  Xi'an University of Science and Technology           China
# 1998        1999                    CEU San Pablo University           Spain
# 1999        2000                           Huzhou University           China
#
# ...

# %%
# Lets take a look at the missing data
missing_data = uni[uni.isin(['-']).any(axis=1)]
missing_data
# Out:
#       World Rank                                 Institution Country  \
# 33            34         University of California, San Diego     USA
# 34            35                        Karolinska Institute  Sweden
# 37            38     University of California, San Francisco     USA
# 48            49                      Rockefeller University     USA
# 57            58                         Tsinghua University   China
# ...          ...                                         ...     ...
# 1995        1996             Santa Catarina State University  Brazil
# 1996        1997            Yancheng Institute of Technology   China
# 1997        1998  Xi'an University of Science and Technology   China
# 1998        1999                    CEU San Pablo University   Spain
# 1999        2000                           Huzhou University   China
#
#       National Rank Quality of Education Rank Alumni Employment Rank  \
# ...

# %%
# The missing data is denoted by the character '-', below we can construct a data frame using only complete record
x = ['-']
uni_complete = uni[ (uni.isin(x).any(axis=1)==False )] 
uni_complete
# Out:
#       World Rank                            Institution         Country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5                   University of Oxford  United Kingdom
# ...          ...                                    ...             ...
# 652          653                  Binghamton University             USA
# 679          680             University of Maine, Orono             USA
# 729          730                      Bangor University  United Kingdom
# 836          837                  University of Wrocław          Poland
# 1096        1097                 University of Calcutta           India
#
#       National Rank Quality of Education Rank Alumni Employment Rank  \
# ...

# %%
# Demonstration of the ability to count per specific attribute
uni['Score'].value_counts()
# Out:
# 65.8     29
# 66.0     28
# 65.9     27
# 66.1     27
# 66.2     27
#          ..
# 86.0      1
# 86.1      1
# 86.3      1
# 86.4      1
# 100.0     1
# Name: Score, Length: 238, dtype: int64

# %% [markdown]
# We can use this information if we were to filter or approach universities within a specific score range

# %%
# Demonstration of the information we can decribe a dataset with
uni.describe()
# Out:
#         World Rank  National Rank        Score
# count  2000.000000    2000.000000  2000.000000
# mean   1000.500000      67.523000    71.586450
# std     577.494589      83.128615     5.079795
# min       1.000000       1.000000    65.700000
# 25%     500.750000      10.000000    67.700000
# 50%    1000.500000      33.000000    70.200000
# 75%    1500.250000      86.000000    74.100000
# max    2000.000000     347.000000   100.000000

# %%
# Histogram's constructed using the columns
uni_complete.hist(bins=181, figsize=(20,15))
plt.show()

# %%
# Scattergraph's constructed using the columns
uni_complete.plot(kind="scatter", y="Alumni Employment Rank", x="Quality of Education Rank", figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Quality of Education Rank', ylabel='Alumni Employment Rank'>

# %%
uni_complete.plot(kind="scatter", y="Quality of Faculty Rank", x="Quality of Education Rank", figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Quality of Education Rank', ylabel='Quality of Faculty Rank'>
