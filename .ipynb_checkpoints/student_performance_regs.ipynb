# %%
import sys
sys.path
from platform import python_version
assert sys.version_info >= (3, 5)
print(python_version())
# Out:
# 3.9.13

# %%
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request
from pylab import rcParams
import seaborn as sb

# %%
import sklearn
assert sklearn.__version__ >= "0.20"
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
from collections import Counter

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
DOWNLOAD_ROOT = "https://github.com/romanfen/F21DL-G6"
UNIS_PATH = os.path.join("Top 2000 Universities of the World - Sheet1.csv")
UNIS_URL = DOWNLOAD_ROOT + "Top 2000 Universities of the World - Sheet1.csv"

# def fetch_housing_data(unis_url = UNIS_URL, unis_path=UNIS_PATH):
#     os.makedirs(unis_path, exist_ok =True)
#     csv_path = os.path.join(UNIS_PATH, "Top 2000 Universities of the World - Sheet1.csv")
#     urllib.request.urlretrieve(unis_url, csv_path)
#     unis_csv =

# %%
def load_uni_data():
    url = "https://raw.githubusercontent.com/romanfen/F21DL-G6/main/Maths.csv"
    #csv_path = os.path.join("https://github.com/romanfen/F21DL-G6/blob/main/Top%202000%20Universities%20of%20the%20World%20-%20Sheet1.csv")
    return pd.read_csv(url)

# %%
stu_perf = load_uni_data()
# unis.columns
# unis["age"]
# unis[['school','age']]
# unis.count()
stu_perf
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
stu_perf.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# stu_perf.sort_values(['Medu'])

# %%
# stu_perf.sort_values(['Medu','G3'], ascending=True)

# %%
# stu_perf_total = stu_perf

# %%
# stu_perf_total['total_grade'] = stu_perf_total['G1'] + stu_perf_total['G2'] + stu_perf_total['G3']

# %%
# stu_perf_total.head(10)

# %%
# total = stu_perf_total['total_grade']

# %%
# stu_perf_total.mean()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
stu_perf.hist(bins=50, figsize=(20,15))

plt.show()

# %%
# np.random.seed(42)

# %%
# import numpy as np

# def split_train_test(data,test_ration):
#     shuffled_indices =np.random.permutation(len(data))
#     test_set_size = int(len(data) * test_ration)
#     test_indices = shuffled_indices[:test_set_size]
#     train_indices = shuffled_indices[test_set_size:]
#     return data.iloc[train_indices], data.iloc[test_indices]

# %%
# train_set, test_set = split_train_test(stu_perf_total,0.2)
# len(train_set)

# %%
# len(test_set)

# %%
# from zlib import crc32

# def test_set_check(identifier, test_ratio):
#     return crc32(np.int64(identifier)) & 0xffffffff < test_ratio * 2**32

# def split_train_test_by_id(data, test_ratio, id_column):
#     ids = data[id_column]
#     in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
#     return data.loc[~in_test_set], data.loc[in_test_set]

# %%
# import hashlib

# def test_set_check(identifier, test_ratio, hash=hashlib.md5):
#     return hash(np.int64(identifier)).digest()[-1]<256 * test_ratio

# %%
# def test_set_check(identifier, test_ratio, hash=hashlib.md5):
#     return bytearray(hash(np.int64(identifier)).digest())[-1] < 256 * test_ratio

# %%
# stu_perf_id =  stu_perf_total.reset_index()
# train_set, test_set = split_train_test_by_id(stu_perf_id, 0.2, "index")

# %%
# stu_perf_id["id"] = stu_perf["G1"] * 1000 + stu_perf["G2"]
# train_set, test_set = split_train_test_by_id(stu_perf_id, 0.2, "id")

# %%
# test_set

# %%
# stu_perf_total.sort_values(by=['school' , 'total_grade'])

# %%
# stu_perf_total[['school','total_grade']]

# %%
# from sklearn.model_selection import train_test_split
# train_set, test_set = train_test_split(stu_perf_total, test_size=0.2, random_state=42)

# %%
# test_set

# %%
stu_perf
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sb.pairplot(stu_perf)

# %%
print(stu_perf.corr())
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
# 1 - predictor variables traveltime and grade 1
#target value grade 2

stu_data = stu_perf.iloc[:,[12,30]].values
stu_target = stu_perf.iloc[:,31].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[30]
# stu_perf.columns[11]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.7316166172192051
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# 2 - predictor absenses and grade 1
#target value grade 2

stu_data = stu_perf.iloc[:,[29,30]].values
stu_target = stu_perf.iloc[:,31].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[30]
# stu_perf.columns[11]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.726133940941236
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# 3 - predictor health and grade 1
#target value grade 2

stu_data = stu_perf.iloc[:,[28,30]].values
stu_target = stu_perf.iloc[:,31].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[30]
# stu_perf.columns[11]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.7273628720766403
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# 1 Mother's education and G2 score
#target is g1

stu_data = stu_perf.iloc[:,[6,31]].values
stu_target = stu_perf.iloc[:,30].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.7265984097215943
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
stu_perf.columns[32]
# Out:
# 'G3'

# %%
# 2 family relationship and G2 score
#target is g1

stu_data = stu_perf.iloc[:,[23,31]].values
stu_target = stu_perf.iloc[:,30].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.7275304495955891
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# 3 time spent going out and G2 score
#target is g1

stu_data = stu_perf.iloc[:,[25,31]].values
stu_target = stu_perf.iloc[:,30].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.7262260549273718
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
stu_perf.columns[27]
# Out:
# 'Walc'

# %%
# 1 out drinking on weekends and G2 score
#target is g3

stu_data = stu_perf.iloc[:,[27,31]].values
stu_target = stu_perf.iloc[:,32].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.8194110298493895
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
stu_perf.columns[28]
# Out:
# 'health'

# %%
# 2 out drinking on week days and G2 score
#target is g3

stu_data = stu_perf.iloc[:,[26,31]].values
stu_target = stu_perf.iloc[:,32].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# 0.8187974159707491
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# 3 health and G2 score
#target is g3

stu_data = stu_perf.iloc[:,[28,31]].values
stu_target = stu_perf.iloc[:,32].values

x,y = scale(stu_data), stu_target
# stu_perf.columns[31]
# stu_perf.columns[6]
# print(x)

LinReg = LinearRegression(normalize =True)
LinReg.fit(x,y)
print(LinReg.score(x,y))
# Out:
# C:\Users\josep\anaconda3\envs\F21DL\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# 0.8195269653429923

# %%
stu_perf
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
subset1 = stu_perf[['health', 'Dalc', 'Walc']]
subset1
# Out:
#      health  Dalc  Walc
# 0         3     1     1
# 1         3     1     1
# 2         3     2     3
# 3         5     1     1
# 4         5     1     2
# ..      ...   ...   ...
# 390       4     4     5
# 391       2     3     4
# 392       3     3     3
# 393       5     3     4
# 394       5     3     3
#
# [395 rows x 3 columns]

# %%
subset2 = stu_perf[['goout', 'famrel', 'Medu']]
subset2
# Out:
#      goout  famrel  Medu
# 0        4       4     4
# 1        3       5     1
# 2        2       4     1
# 3        2       3     4
# 4        2       4     3
# ..     ...     ...   ...
# 390      4       5     2
# 391      5       2     3
# 392      3       5     1
# 393      1       4     3
# 394      3       3     1
#
# [395 rows x 3 columns]

# %%
subset3 = stu_perf[['health', 'absences', 'traveltime']]
subset3
# Out:
#      health  absences  traveltime
# 0         3         6           2
# 1         3         4           1
# 2         3        10           1
# 3         5         2           1
# 4         5         4           1
# ..      ...       ...         ...
# 390       4        11           1
# 391       2         3           2
# 392       3         3           1
# 393       5         0           3
# 394       5         5           1
#
# [395 rows x 3 columns]
