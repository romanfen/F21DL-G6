# %%
import sys
sys.path
from platform import python_version
assert sys.version_info >= (3, 5)
print(python_version())
# Out:
# 3.9.13

# %%
import sklearn
assert sklearn.__version__ >= "0.20"

# %%
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# DOWNLOAD_ROOT = "https://github.com/romanfen/F21DL-G6"
# UNIS_PATH = os.path.join("Top 2000 Universities of the World - Sheet1.csv")
# UNIS_URL = DOWNLOAD_ROOT + "Top 2000 Universities of the World - Sheet1.csv"

# def fetch_housing_data(unis_url = UNIS_URL, unis_path=UNIS_PATH):
#     os.makedirs(unis_path, exist_ok =True)
#     csv_path = os.path.join(UNIS_PATH, "Top 2000 Universities of the World - Sheet1.csv")
#     urllib.request.urlretrieve(unis_url, csv_path)
#     unis_csv =

# %%
def load_uni_data():
    url = "https://raw.githubusercontent.com/romanfen/F21DL-G6/main/Top%202000%20Universities%20of%20the%20World%20-%20Sheet1.csv"
    #csv_path = os.path.join("https://github.com/romanfen/F21DL-G6/blob/main/Top%202000%20Universities%20of%20the%20World%20-%20Sheet1.csv")
    return pd.read_csv(url)

# %%
unis = load_uni_data()
unis.head()
# Out:
#    World Rank                            Institution         Country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    National Rank Quality of Education Rank Alumni Employment Rank  \
# 0              1                         1                      1
# 1              2                         4                     12
# 2              3                        10                      4
# 3              1                         3                     25
# 4              2                         7                     27
#
#   Quality of Faculty Rank Research Performance Rank  Score
# 0                       1                         1  100.0
# ...

# %%
x = ['-']
y = ["USA", "United Kingdom"]
new_unis = unis[ (unis.any(axis=1).isin(x)==False )] 

new_unis.head()
# Out:
#    World Rank                            Institution         Country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    National Rank Quality of Education Rank Alumni Employment Rank  \
# 0              1                         1                      1
# 1              2                         4                     12
# 2              3                        10                      4
# 3              1                         3                     25
# 4              2                         7                     27
#
#   Quality of Faculty Rank Research Performance Rank  Score
# 0                       1                         1  100.0
# ...

# %%
new_unis.hist(bins=50, figsize=(20,15))
plt.show()

# %%
new_unis.plot(kind="scatter", x="Score", y="National Rank")
# Out:
# <AxesSubplot:xlabel='Score', ylabel='National Rank'>

# %%
new_unis.plot(kind="scatter", x="Alumni Employment Rank", y="National Rank")
# Out:
# <AxesSubplot:xlabel='Alumni Employment Rank', ylabel='National Rank'>
